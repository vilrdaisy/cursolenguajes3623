# %%
print("TALLER 17 DE FEBRERO 2023")
def captura_datos(nom,apell,dir,tel,edad1,est_civil,numerhijo,estatu,fech_contrato,suel_basico,d_laborados):
  print("\n ***DATOS FUNCIONARIO***")
  print("Numero Identificacion: ",(numidentif))
  print("Nombres y Apellidos: ",(nombres+" "+apellidos))
  print("Direccion: ",(direccion))
  print("Telefono: ",(telefono))
  print("Edad: ",(edad))
  print("Estado Civil: ",(estado_civil))
  print("Numeros Hijos: ",(numhijos))
  print("Estatura en cm: ",(estatura))
  print("Fecha Contratacion: ",(fecha_contrata))
  print("Sueldo Base:$ ",(sueldo_basico))
  print("Dias Laborados en el mes: ",(dias_laborados))
  print("\n **BENEFICIOS PARA EL EMPLEADO**")
  # Uso Sentencia condicicional. Si el empleado es mayor de 55 años, disfruta bono prepension 5% de su sueldo basico.
  if edad > 55:
    bono_prepension = float(sueldo_basico * 0.05)
    print("Su bono prepension es de: ${:,.2f}".format(bono_prepension))
  else:
    print("\n El empleado no tiene bono prepensionado")
    # Si el empleado es casado y tiene hijos se le otorgará un paseo cada diciembre
  if numhijos > 0 and estado_civil == "casada" or estado_civil == "casado":
    print("\n PASEO EN DICIEMBRE !")
    
  else:
    print("\n No cumple con las condiciones para beneficio de paseo en diciembre")
  # Si el sueldo básico está entre 1000000 y 1500000 tendrá una comisión del 2% sobre el valor del sueldo;
  # Si el sueldo básico está entre 1500001 y 2000000 tendrá una comisión del 5% sobre el valor del sueldo;
  # para todos los demás casos no habrá comisión.
  if sueldo_basico >= 1000000 and sueldo_basico <= 1500000:
    comision1 = float(sueldo_basico * 0.02)
    print("Su Comision 2% es: ${:,.2f}".format(comision1))
  elif sueldo_basico >= 1500001 and sueldo_basico <= 2000000 :
    comision2 = float(sueldo_basico * 0.05)
    print("\n Su Comision 5% es: ${:,.2f}".format(comision2))
    # Si el empleado trabajó más de 20 días al mes y su sueldo es menor a 1000000 tendrá derecho a un bono de alimentación.
  elif sueldo_basico < 1000000 and dias_laborados > 20:
      print("\n TIENE BONO DE ALIMENTACION!!")
  else:
    print("\n SIN BONOS ALIMENTACION")

respuesta = "si"
while respuesta == "si" or respuesta == "s" or respuesta == "SI":
    numidentif=input("Digite C.C. :")
    nombres=input("Digite Nombres: ")
    apellidos=input("Digite Apellidos: ")
    direccion=input("Direccion: ")
    telefono=input("Digite Numero Telefono: ")
    edad=int(input("Digite Edad: "))
    estado_civil=input("Digite Estado Civil: ")
    numhijos=int(input("Digite Numero hijos: "))
    estatura=input("Digite Estatura en cm: ")
    fecha_contrata=input("Digite Fecha Contratacion dd/mm/aa: ")
    sueldo_basico=int(input("Digite sueldo basico: "))
    dias_laborados=int(input("Digite Dias Laborados: "))
    captura_datos(nombres,apellidos,direccion,telefono,edad,estado_civil,numhijos,estatura,fecha_contrata,sueldo_basico,dias_laborados)

    respuesta = input("\n ¿Desea Ingresar datos de otro funcionario: ?")
# Out:
# TALLER 17 DE FEBRERO 2023
# Digite C.C. :12
# Digite Nombres: Lili
# Digite Apellidos: Lopez
# Direccion: calle 100
# Digite Numero Telefono: 310456789
# Digite Edad: 25
# Digite Estado Civil: soltera
# Digite Numero hijos: 1
# Digite Estatura en cm: 170
# Digite Fecha Contratacion dd/mm/aa: 02/01/22
# Digite sueldo basico: 1500000
# Digite Dias Laborados: 23
#
#  ***DATOS FUNCIONARIO***
# Numero Identificacion:  12
# Nombres y Apellidos:  Lili Lopez
# Direccion:  calle 100
# Telefono:  310456789
# Edad:  25
# Estado Civil:  soltera
# Numeros Hijos:  1
# Estatura en cm:  170
# Fecha Contratacion:  02/01/22
# Sueldo Base:$  1500000
# Dias Laborados en el mes:  23
#
#  **BENEFICIOS PARA EL EMPLEADO**
#
#  El empleado no tiene bono prepensionado
#
#  No cumple con las condiciones para beneficio de paseo en diciembre
# Su Comision 2% es: $30,000.00
# ¿Desea Ingresar datos de otro funcionario: ?SI
# Digite C.C. :565656565
# Digite Nombres: Pedro
# Digite Apellidos: Sanchez
# ...
